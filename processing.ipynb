# %%
import pandas as pd 

ds = pd.read_csv('charts.csv')
ds.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
import pandas as pd

df = pd.read_csv("charts.csv")

df = df[df['region'] == 'United States']
df = df[df['chart'] == 'top200']
df.insert(4, 'artist count', 1)

df.head()
# Out:
#                                     title  rank        date  \
# 8246  Bad and Boujee (feat. Lil Uzi Vert)     1  2017-01-01
# 8247                            Fake Love     2  2017-01-01
# 8248                              Starboy     3  2017-01-01
# 8249                               Closer     4  2017-01-01
# 8250                        Black Beatles     5  2017-01-01
#
#                         artist  artist count  \
# 8246                     Migos             1
# 8247                     Drake             1
# 8248     The Weeknd, Daft Punk             1
# 8249  The Chainsmokers, Halsey             1
# 8250  Rae Sremmurd, Gucci Mane             1
#
#                                                     url         region  \
# 8246  https://open.spotify.com/track/4Km5HrUvYTaSUfi...  United States
# 8247  https://open.spotify.com/track/343YBumqHu19cGo...  United States
# 8248  https://open.spotify.com/track/5aAx2yezTd8zXrk...  United States
# 8249  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  United States
# 8250  https://open.spotify.com/track/6fujklziTHa8uoM...  United States
#
#        chart          trend    streams
# 8246  top200  SAME_POSITION  1371493.0
# 8247  top200  SAME_POSITION  1180074.0
# 8248  top200  SAME_POSITION  1064351.0
# 8249  top200  SAME_POSITION  1010492.0
# 8250  top200  SAME_POSITION   874289.0

# %%
df['artist count'] = df['artist'].apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)

df.head()
# Out:
#                                     title  rank        date  \
# 8246  Bad and Boujee (feat. Lil Uzi Vert)   1.0  2017-01-01
# 8247                            Fake Love   2.0  2017-01-01
# 8248                              Starboy   3.0  2017-01-01
# 8249                               Closer   4.0  2017-01-01
# 8250                        Black Beatles   5.0  2017-01-01
#
#                         artist  artist count  \
# 8246                     Migos             1
# 8247                     Drake             1
# 8248     The Weeknd, Daft Punk             2
# 8249  The Chainsmokers, Halsey             2
# 8250  Rae Sremmurd, Gucci Mane             2
#
#                                                     url         region  \
# 8246  https://open.spotify.com/track/4Km5HrUvYTaSUfi...  United States
# 8247  https://open.spotify.com/track/343YBumqHu19cGo...  United States
# 8248  https://open.spotify.com/track/5aAx2yezTd8zXrk...  United States
# 8249  https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  United States
# 8250  https://open.spotify.com/track/6fujklziTHa8uoM...  United States
#
#        chart          trend    streams
# 8246  top200  SAME_POSITION  1371493.0
# 8247  top200  SAME_POSITION  1180074.0
# 8248  top200  SAME_POSITION  1064351.0
# 8249  top200  SAME_POSITION  1010492.0
# 8250  top200  SAME_POSITION   874289.0

# %%
from sklearn.preprocessing import LabelEncoder
from nltk.stem import PorterStemmer

chart_encoder = LabelEncoder()
trend_encoder = LabelEncoder()

df['chart_encoded'] = chart_encoder.fit_transform(df['chart'])
df['trend_encoded'] = trend_encoder.fit_transform(df['trend'])

stemmer = PorterStemmer()

def stem_text(text):
    if isinstance(text, str):
        stemmed_words = [stemmer.stem(word) for word in text.split()]
        return ' '.join(stemmed_words)
    return ''

df['title'] = df['title'].apply(stem_text)
df['artist'] = df['artist'].apply(stem_text)

df.to_csv("processed_charts.csv", index=False)

# %%
import pandas as pd 

df2 = pd.read_csv('processed_charts.csv')
df2[:20]
# Out:
#                                                 title  rank        date  \
# 0                   bad and bouj (feat. lil uzi vert)   1.0  2017-01-01
# 1                                           fake love   2.0  2017-01-01
# 2                                             starboy   3.0  2017-01-01
# 3                                              closer   4.0  2017-01-01
# 4                                         black beatl   5.0  2017-01-01
# 5                         broccoli (feat. lil yachty)   6.0  2017-01-01
# 6                                            one danc   7.0  2017-01-01
# 7                                             carolin   8.0  2017-01-01
# 8                                     let me love you   9.0  2017-01-01
# 9                                          bounc back  10.0  2017-01-01
# 10                                     i feel it come  11.0  2017-01-01
# 11                                          24k magic  12.0  2017-01-01
# 12                    bad thing (with camila cabello)  13.0  2017-01-01
# 13                                   x (feat. future)  14.0  2017-01-01
# 14  i don’t wanna live forev (fifti shade darker) ...  15.0  2017-01-01
# 15                                   don't wanna know  16.0  2017-01-01
# 16               chill bill (feat. j. davi$ & spooks)  17.0  2017-01-01
# 17                                            deja vu  18.0  2017-01-01
# 18                                             ooouuu  19.0  2017-01-01
# 19                                      parti monster  20.0  2017-01-01
#
#                       artist  artist count  \
# 0                       migo             1
# 1                      drake             1
# 2      the weeknd, daft punk             2
# 3   the chainsmokers, halsey             2
# 4   rae sremmurd, gucci mane             2
# 5           shelley fka dram             1
# 6        drake, wizkid, kyla             3
# 7                      aminé             1
# 8    dj snake, justin bieber             2
# 9                   big sean             1
# 10     the weeknd, daft punk             2
# 11                 bruno mar             1
# 12          machin gun kelli             1
# 13   21 savage, metro boomin             2
# 14        zayn, taylor swift             2
# 15  maroon 5, kendrick lamar             2
# 16                 rob $tone             1
# 17                   j. cole             1
# 18                 young m.a             1
# 19                the weeknd             1
#
#                                                   url         region   chart  \
# 0   https://open.spotify.com/track/4Km5HrUvYTaSUfi...  United States  top200
# 1   https://open.spotify.com/track/343YBumqHu19cGo...  United States  top200
# 2   https://open.spotify.com/track/5aAx2yezTd8zXrk...  United States  top200
# 3   https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  United States  top200
# 4   https://open.spotify.com/track/6fujklziTHa8uoM...  United States  top200
# 5   https://open.spotify.com/track/7yyRTcZmCiyzzJl...  United States  top200
# 6   https://open.spotify.com/track/1xznGGDReH1oQq0...  United States  top200
# 7   https://open.spotify.com/track/7FB8l7UA1HKqnuS...  United States  top200
# 8   https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  United States  top200
# 9   https://open.spotify.com/track/0SGkqnVQo9KPytS...  United States  top200
# 10  https://open.spotify.com/track/5GXAXm5YOmYT0kL...  United States  top200
# 11  https://open.spotify.com/track/6b8Be6ljOzmkOmF...  United States  top200
# 12  https://open.spotify.com/track/1PSBzsahR2AKwLJ...  United States  top200
# 13  https://open.spotify.com/track/6fwdbPMwP1zVStm...  United States  top200
# 14  https://open.spotify.com/track/3NdDpSvN911VPGi...  United States  top200
# 15  https://open.spotify.com/track/5MFzQMkrl1FOOng...  United States  top200
# 16  https://open.spotify.com/track/5uDASfU19gDxSjW...  United States  top200
# 17  https://open.spotify.com/track/6I6NX6tjGsxFAsI...  United States  top200
# 18  https://open.spotify.com/track/7JYsArznYOjX2js...  United States  top200
# 19  https://open.spotify.com/track/4F7A0DXBrmUAkp3...  United States  top200
#
#             trend    streams  chart_encoded  trend_encoded
# 0   SAME_POSITION  1371493.0              0              3
# 1   SAME_POSITION  1180074.0              0              3
# 2   SAME_POSITION  1064351.0              0              3
# 3   SAME_POSITION  1010492.0              0              3
# 4   SAME_POSITION   874289.0              0              3
# 5         MOVE_UP   763259.0              0              1
# 6         MOVE_UP   753150.0              0              1
# 7       MOVE_DOWN   714839.0              0              0
# 8         MOVE_UP   690483.0              0              1
# 9       MOVE_DOWN   682688.0              0              0
# 10  SAME_POSITION   651807.0              0              3
# 11        MOVE_UP   574974.0              0              1
# 12      MOVE_DOWN   567789.0              0              0
# 13        MOVE_UP   544620.0              0              1
# 14      MOVE_DOWN   507450.0              0              0
# 15        MOVE_UP   486364.0              0              1
# 16        MOVE_UP   485127.0              0              1
# 17      MOVE_DOWN   478503.0              0              0
# 18        MOVE_UP   456308.0              0              1
# 19  SAME_POSITION   456291.0              0              3
